# %% [markdown]
# Starting out importing the dataset.

# %%
from pathlib import Path

path = "../../Data" # Need to change this when migrating from the current directory
data_files = [f for f in Path(path).iterdir() if f.is_file()]

for file in data_files:

# %% [markdown]
# Reading the configuration from the config.json file

# %%
import json
from pathlib import Path

path = "../../config.json"

with open(path, 'r') as config:
    data = json.load(config)
